# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv('cat-in-the-dat-ii/train.csv')
df
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2  \
# 0            0    0.0    0.0    0.0     F     N   Red  Trapezoid  Hamster
# 1            1    1.0    1.0    0.0     F     Y   Red       Star  Axolotl
# 2            2    0.0    1.0    0.0     F     N   Red        NaN  Hamster
# 3            3    NaN    0.0    0.0     F     N   Red     Circle  Hamster
# 4            4    0.0    NaN    0.0     T     N   Red   Triangle  Hamster
# ...        ...    ...    ...    ...   ...   ...   ...        ...      ...
# 599995  599995    0.0    1.0    0.0     T     N   Red    Polygon  Axolotl
# 599996  599996    1.0    0.0    0.0     T     Y  Blue    Polygon      Dog
# 599997  599997    0.0    0.0    0.0     F     Y   Red     Circle  Axolotl
# 599998  599998    1.0    1.0    0.0     F     Y   NaN    Polygon  Axolotl
# 599999  599999    0.0    0.0    0.0     T     N  Blue   Triangle      Dog
#
#              nom_3  ...      nom_9 ord_0        ord_1        ord_2 ord_3  \
# ...

# %%
sn.histplot(df.target.astype(str))
plt.plot()

df.target.value_counts()
# given that the target has a very different proportion we defined this target as skewed
# Out:
# 0    487677
# 1    112323
# Name: target, dtype: int64

# %%
#rename ord_2
mapping = {'Freezing':0,'Warm':1, 'Cold':2,'Boiling Hot':3, 'Hot':4, 'Lava Hot':5}

df['ord_2'] = df.ord_2.map(mapping)

# %%
df.ord_2.value_counts()
# Out:
# 0.0    142726
# 1.0    124239
# 2.0     97822
# 3.0     84790
# 4.0     67508
# 5.0     64840
# Name: ord_2, dtype: int64

# %%
# label encoding using sklearn
import pandas as pd 
from sklearn import preprocessing

df = pd.read_csv('cat-in-the-dat-ii/train.csv')
df.ord_2 = df.ord_2.fillna('NONE')

# initialise LabelEncoder
lbl_enc = preprocessing.LabelEncoder()
df['ord_2v2'] = lbl_enc.fit_transform(df.ord_2.values)
df.ord_2v2.value_counts()
# Out:
# 2    142726
# 6    124239
# 1     97822
# 0     84790
# 3     67508
# 4     64840
# 5     18075
# Name: ord_2v2, dtype: int64

# %%
which(df.ord_2
# Out:
# 0                 Hot
# 1                Warm
# 2            Freezing
# 3            Lava Hot
# 4                Cold
#              ...
# 599995       Freezing
# 599996    Boiling Hot
# 599997       Freezing
# 599998           Warm
# 599999    Boiling Hot
# Name: ord_2, Length: 600000, dtype: object

# %%
ohe = preprocessing.OneHotEncoder(sparse_output=True)
df_v2 = ohe.fit_transform(df.ord_2.values.reshape(-1,1))
df.ord_2.values.reshape(-1,1)
# Out:
# array([['Hot'],
#        ['Warm'],
#        ['Freezing'],
#        ...,
#        ['Freezing'],
#        ['Warm'],
#        ['Boiling Hot']], dtype=object)
